# %%
import pandas as pd
import seaborn as sns
import matplotlib.pylab as plt
import numpy as np

# %%
data = pd.read_csv(r'C:\Users\HP\Documents\python\diplom\parsed_texts\pars.csv')

# %%
display(data)
# Out:
#         year                                               text  birthdate
# 0       2019  \n\n Эта страничка посвящена бижутерии которую...       1980
# 1       2010  \n\n Колье делала на конкурс, получила приз зр...       1980
# 2       2010  \n\n Весна... листочки распускаются, но как то...       1980
# 3       2010  \n\n Новенький браслет и колье в тему к старен...       1980
# 4       2010  \n\n       Материал: цернит, фимо, золотистая ...       1980
# ...      ...                                                ...        ...
# 431679  2006  \n\nЯ просыпаюсь и смеюсь доколиков\n\nДеньги ...       1984
# 431680  2006                   \n\n?кто торгует лекарством?я?\n       1984
# 431681  2006      \n\nэто соседи с верху чистили пятки в окно\n       1984
# 431682  2007                                       \n\nНеверю\n       1984
# 431683  2007      \n\nC2H5OH \n\n\nВремя действия ограничено.\n       1984
#
# [431684 rows x 3 columns]

# %%
# Draw Stripplot
fig, ax = plt.subplots(figsize=(45,30), dpi= 80)    
sns.stripplot(data.birthdate, data.year, jitter=0.25, size=8, ax=ax, linewidth=.5)

# Decorations
plt.title('Стата по возрастам авторов', fontsize=22)
plt.show()
# Out:
# c:\Users\HP\AppData\Local\Programs\Python\Python38\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
